# %%
import json
from pandas import json_normalize
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

import seaborn as sns

# %%
# !pip install statsbombpy
# !pip install mplsoccer

# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# C:\Users\connie\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 18              43          3             International
# 19            1238        108                     India
# 20              11         90                     Spain
# 21              11         42                     Spain
# 22              11          4                     Spain
# 23              11          1                     Spain
# 24              11          2                     Spain
# 25              11         27                     Spain
# 26              11         26                     Spain
# 27              11         25                     Spain
# 28              11         24                     Spain
# 29              11         23                     Spain
# 30              11         22                     Spain
# 31              11         21                     Spain
# 32              11         41                     Spain
# 33              11         40                     Spain
# 34              11         39                     Spain
# 35              11         38                     Spain
# 36              11         37                     Spain
# 37              49          3  United States of America
# 38               2         44                   England
# 39              55         43                    Europe
# 40              53        106                    Europe
# 41              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# 1          Champions League               male              False
# 2          Champions League               male              False
# 3          Champions League               male              False
# 4          Champions League               male              False
# 5          Champions League               male              False
# 6          Champions League               male              False
# 7          Champions League               male              False
# 8          Champions League               male              False
# 9          Champions League               male              False
# 10         Champions League               male              False
# 11         Champions League               male              False
# 12         Champions League               male              False
# 13         Champions League               male              False
# 14         Champions League               male              False
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 18           FIFA World Cup               male              False
# 19      Indian Super league               male              False
# 20                  La Liga               male              False
# 21                  La Liga               male              False
# 22                  La Liga               male              False
# 23                  La Liga               male              False
# 24                  La Liga               male              False
# 25                  La Liga               male              False
# 26                  La Liga               male              False
# 27                  La Liga               male              False
# 28                  La Liga               male              False
# 29                  La Liga               male              False
# 30                  La Liga               male              False
# 31                  La Liga               male              False
# 32                  La Liga               male              False
# 33                  La Liga               male              False
# 34                  La Liga               male              False
# 35                  La Liga               male              False
# 36                  La Liga               male              False
# 37                     NWSL             female              False
# 38           Premier League               male              False
# 39                UEFA Euro               male              False
# 40        UEFA Women's Euro             female              False
# 41        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# 0                       False   2018/2019  2022-08-14T16:57:15.866765
# 1                       False   2017/2018  2021-08-27T11:26:39.802832
# 2                       False   2016/2017  2021-08-27T11:26:39.802832
# 3                       False   2015/2016  2021-08-27T11:26:39.802832
# 4                       False   2014/2015  2021-08-27T11:26:39.802832
# 5                       False   2013/2014  2021-08-27T11:26:39.802832
# 6                       False   2012/2013  2021-08-27T11:26:39.802832
# 7                       False   2011/2012  2021-08-27T11:26:39.802832
# 8                       False   2010/2011  2022-01-26T21:07:11.033473
# 9                       False   2009/2010  2022-02-12T16:13:49.294747
# 10                      False   2008/2009  2021-11-07T14:20:01.699993
# 11                      False   2006/2007  2021-03-31T04:18:30.437060
# 12                      False   2004/2005  2021-04-01T06:18:57.459032
# 13                      False   2003/2004  2021-04-01T00:34:59.472485
# 14                      False   1999/2000            2020-07-29T05:00
# 15                      False   2020/2021  2022-08-16T02:10:37.220648
# 16                      False   2019/2020     2021-06-01T13:01:18.188
# 17                      False   2018/2019  2022-09-12T21:06:25.061309
# 18                       True        2018  2022-09-05T17:17:56.670896
# 19                      False   2021/2022  2022-06-08T12:40:59.857067
# 20                      False   2020/2021     2022-02-11T14:56:09.076
# 21                      False   2019/2020  2022-07-15T23:27:24.260122
# 22                      False   2018/2019  2022-08-30T23:25:57.118855
# 23                      False   2017/2018  2022-08-13T23:18:38.928566
# 24                      False   2016/2017  2022-01-25T22:51:59.353598
# 25                      False   2015/2016  2022-08-30T13:15:37.855155
# 26                      False   2014/2015  2022-08-14T18:49:03.341489
# 27                      False   2013/2014  2022-07-23T12:18:49.547396
# 28                      False   2012/2013  2022-09-25T20:52:24.444609
# 29                      False   2011/2012            2020-07-29T05:00
# 30                      False   2010/2011  2021-11-11T22:57:42.361902
# 31                      False   2009/2010  2021-10-26T13:56:40.989214
# 32                      False   2008/2009            2020-07-29T05:00
# 33                      False   2007/2008  2021-10-26T13:13:56.180589
# 34                      False   2006/2007            2020-07-29T05:00
# 35                      False   2005/2006  2022-07-03T12:34:31.749038
# 36                      False   2004/2005            2020-07-29T05:00
# 37                      False        2018  2021-11-06T05:53:29.435016
# 38                      False   2003/2004  2021-11-14T22:29:00.646120
# 39                       True        2020  2022-02-01T17:20:34.319496
# 40                       True        2022  2022-08-01T07:46:11.595364
# 41                       True        2019  2022-07-13T20:21:27.033445
#
#              match_updated_360         match_available_360  \
# 0      2021-06-13T16:17:31.694                        None
# 1      2021-06-13T16:17:31.694                        None
# 2      2021-06-13T16:17:31.694                        None
# 3      2021-06-13T16:17:31.694                        None
# 4      2021-06-13T16:17:31.694                        None
# 5      2021-06-13T16:17:31.694                        None
# 6      2021-06-13T16:17:31.694                        None
# 7      2021-06-13T16:17:31.694                        None
# 8      2021-06-13T16:17:31.694                        None
# 9      2021-06-13T16:17:31.694                        None
# 10     2021-06-13T16:17:31.694                        None
# 11     2021-06-13T16:17:31.694                        None
# 12     2021-06-13T16:17:31.694                        None
# 13     2021-06-13T16:17:31.694                        None
# 14     2021-06-13T16:17:31.694                        None
# 15     2021-06-13T16:17:31.694                        None
# 16     2021-06-13T16:17:31.694                        None
# 17     2021-06-13T16:17:31.694                        None
# 18     2021-06-13T16:17:31.694                        None
# 19                        None                        None
# 20  2022-08-16T21:50:36.812060  2022-08-16T21:50:36.812060
# 21     2021-06-13T16:17:31.694                        None
# 22  2021-07-09T14:53:22.103024                        None
# 23     2021-06-13T16:17:31.694                        None
# 24     2021-06-13T16:17:31.694                        None
# 25     2021-06-13T16:17:31.694                        None
# 26     2021-06-13T16:17:31.694                        None
# 27     2021-06-13T16:17:31.694                        None
# 28     2021-06-13T16:17:31.694                        None
# 29     2021-06-13T16:17:31.694                        None
# 30     2021-06-13T16:17:31.694                        None
# 31     2021-06-13T16:17:31.694                        None
# 32     2021-06-13T16:17:31.694                        None
# 33     2021-06-13T16:17:31.694                        None
# 34     2021-06-13T16:17:31.694                        None
# 35     2021-06-13T16:17:31.694                        None
# 36     2021-06-13T16:17:31.694                        None
# 37     2021-06-13T16:17:31.694                        None
# 38     2021-06-13T16:17:31.694                        None
# 39            2022-08-04T12:00            2022-08-04T12:00
# 40  2022-09-13T17:04:11.418708  2022-09-13T17:04:11.418708
# 41     2021-06-13T16:17:31.694                        None
#
#                match_available
# 0   2022-08-14T16:57:15.866765
# 1   2021-01-23T21:55:30.425330
# 2             2020-07-29T05:00
# 3             2020-07-29T05:00
# 4             2020-07-29T05:00
# 5             2020-07-29T05:00
# 6      2021-07-10T13:41:45.751
# 7             2020-07-29T05:00
# 8   2022-01-26T21:07:11.033473
# 9   2022-02-12T16:13:49.294747
# 10  2021-11-07T14:20:01.699993
# 11  2021-03-31T04:18:30.437060
# 12  2021-04-01T06:18:57.459032
# 13  2021-04-01T00:34:59.472485
# 14            2020-07-29T05:00
# 15  2022-08-16T02:10:37.220648
# 16     2021-06-01T13:01:18.188
# 17  2022-09-12T21:06:25.061309
# 18  2022-09-05T17:17:56.670896
# 19  2022-06-08T12:40:59.857067
# 20     2022-02-11T14:56:09.076
# 21  2022-07-15T23:27:24.260122
# 22  2022-08-30T23:25:57.118855
# 23  2022-08-13T23:18:38.928566
# 24  2022-01-25T22:51:59.353598
# 25  2022-08-30T13:15:37.855155
# 26  2022-08-14T18:49:03.341489
# 27  2022-07-23T12:18:49.547396
# 28  2022-09-25T20:52:24.444609
# 29            2020-07-29T05:00
# 30  2021-11-11T22:57:42.361902
# 31  2021-10-26T13:56:40.989214
# 32            2020-07-29T05:00
# 33  2021-10-26T13:13:56.180589
# 34            2020-07-29T05:00
# 35  2022-07-03T12:34:31.749038
# 36            2020-07-29T05:00
# 37  2021-11-06T05:53:29.435016
# 38  2021-11-14T22:29:00.646120
# 39  2022-02-01T17:20:34.319496
# 40  2022-08-01T07:46:11.595364
# 41  2022-07-13T20:21:27.033445

# %%
df = sb.matches(competition_id=53, season_id=106)
df.info()
# Out:
# C:\Users\connie\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   match_id               31 non-null     int64
#  1   match_date             31 non-null     object
#  2   kick_off               31 non-null     object
#  3   competition            31 non-null     object
#  4   season                 31 non-null     object
#  5   home_team              31 non-null     object
#  6   away_team              31 non-null     object
#  7   home_score             31 non-null     int64
#  8   away_score             31 non-null     int64
#  9   match_status           31 non-null     object
#  10  match_status_360       31 non-null     object
#  11  last_updated           31 non-null     object
#  12  last_updated_360       31 non-null     object
#  13  match_week             31 non-null     int64
#  14  competition_stage      31 non-null     object
#  15  stadium                31 non-null     object
#  16  referee                31 non-null     object
#  17  home_managers          31 non-null     object
#  18  away_managers          31 non-null     object
#  19  data_version           31 non-null     object
#  20  shot_fidelity_version  31 non-null     object
#  21  xy_fidelity_version    31 non-null     object
# dtypes: int64(4), object(18)
# memory usage: 5.5+ KB

# %%
matches_touse = df.match_id.values.tolist()
matches_touse
# Out:
# [3847567,
#  3845506,
#  3835335,
#  3835323,
#  3835325,
#  3835324,
#  3835331,
#  3835320,
#  3845507,
#  3844387,
#  3844384,
#  3844385,
#  3844386,
#  3835342,
#  3835337,
#  3835338,
#  3835330,
#  3835329,
#  3835322,
#  3835332,
#  3835327,
#  3835326,
#  3835341,
#  3835340,
#  3835339,
#  3835336,
#  3835334,
#  3835328,
#  3835333,
#  3835321,
#  3835319]

# %%
#df = sb.matches(match_id=3847567)

# %%
events = sb.events(match_id=3835336)
events
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 3640   NaN                NaN                  NaN                     NaN
# 3641   NaN                NaN                  NaN                     NaN
# 3642   NaN                NaN                  NaN                     NaN
# 3643   NaN                NaN                  NaN                     NaN
# 3644   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                               NaN              NaN             NaN
# 1                               NaN              NaN             NaN
# 2                               NaN              NaN             NaN
# 3                               NaN              NaN             NaN
# 4                               NaN              NaN             NaN
# ...                             ...              ...             ...
# 3640                            NaN              NaN             NaN
# 3641                            NaN              NaN             NaN
# 3642                            NaN              NaN             NaN
# 3643                            NaN              NaN             NaN
# 3644                            NaN              NaN             NaN
#
#      carry_end_location clearance_aerial_won clearance_body_part  ...  \
# 0                   NaN                  NaN                 NaN  ...
# 1                   NaN                  NaN                 NaN  ...
# 2                   NaN                  NaN                 NaN  ...
# 3                   NaN                  NaN                 NaN  ...
# 4                   NaN                  NaN                 NaN  ...
# ...                 ...                  ...                 ...  ...
# 3640                NaN                  NaN                 NaN  ...
# 3641                NaN                  NaN                 NaN  ...
# 3642                NaN                  NaN                 NaN  ...
# 3643                NaN                  NaN                 NaN  ...
# 3644                NaN                  NaN                 NaN  ...
#
#      shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0                  NaN            NaN       NaN                  NaN
# 1                  NaN            NaN       NaN                  NaN
# 2                  NaN            NaN       NaN                  NaN
# 3                  NaN            NaN       NaN                  NaN
# 4                  NaN            NaN       NaN                  NaN
# ...                ...            ...       ...                  ...
# 3640               NaN            NaN       NaN             Tactical
# 3641               NaN            NaN       NaN                  NaN
# 3642               NaN            NaN       NaN                  NaN
# 3643               NaN            NaN       NaN                  NaN
# 3644               NaN            NaN       NaN                  NaN
#
#      substitution_replacement  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 3640         Marina Georgieva
# 3641                      NaN
# 3642                      NaN
# 3643                      NaN
# 3644                      NaN
#
#                                                 tactics             team  \
# 0     {'formation': 4141, 'lineup': [{'player': {'id...  Austria Women's
# 1     {'formation': 4231, 'lineup': [{'player': {'id...   Norway Women's
# 2                                                   NaN  Austria Women's
# 3                                                   NaN   Norway Women's
# 4                                                   NaN  Austria Women's
# ...                                                 ...              ...
# 3640                                                NaN  Austria Women's
# 3641  {'formation': 4231, 'lineup': [{'player': {'id...   Norway Women's
# 3642  {'formation': 4141, 'lineup': [{'player': {'id...  Austria Women's
# 3643  {'formation': 4231, 'lineup': [{'player': {'id...   Norway Women's
# 3644  {'formation': 343, 'lineup': [{'player': {'id'...  Austria Women's
#
#          timestamp            type  under_pressure
# 0     00:00:00.000     Starting XI             NaN
# 1     00:00:00.000     Starting XI             NaN
# 2     00:00:00.000      Half Start             NaN
# 3     00:00:00.000      Half Start             NaN
# 4     00:00:00.000      Half Start             NaN
# ...            ...             ...             ...
# 3640  00:42:08.424    Substitution             NaN
# 3641  00:18:59.932  Tactical Shift             NaN
# 3642  00:26:48.051  Tactical Shift             NaN
# 3643  00:36:34.809  Tactical Shift             NaN
# 3644  00:42:46.989  Tactical Shift             NaN
#
# [3645 rows x 93 columns]

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

all_events = pd.DataFrame()
for match in matches_touse:
    events = sb.events(match_id=match)
    all_events = pd.concat([all_events, events], axis = 0)

# events.to_csv('events_test_1.csv')

all_events
# Out:
# C:\Users\connie\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#      50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                NaN                  NaN                     NaN
# 1      NaN                NaN                  NaN                     NaN
# 2      NaN                NaN                  NaN                     NaN
# 3      NaN                NaN                  NaN                     NaN
# 4      NaN                NaN                  NaN                     NaN
# ...    ...                ...                  ...                     ...
# 3435   NaN                NaN                  NaN                     NaN
# 3436   NaN                NaN                  NaN                     NaN
# 3437   NaN                NaN                  NaN                     NaN
# 3438   NaN                NaN                  NaN                     NaN
# 3439   NaN                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 0                               NaN              NaN                NaN
# 1                               NaN              NaN                NaN
# 2                               NaN              NaN                NaN
# 3                               NaN              NaN                NaN
# 4                               NaN              NaN                NaN
# ...                             ...              ...                ...
# 3435                            NaN              NaN                NaN
# 3436                            NaN              NaN                NaN
# 3437                            NaN              NaN                NaN
# 3438                            NaN              NaN                NaN
# 3439                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 0                     NaN                 NaN            NaN
# 1                     NaN                 NaN            NaN
# 2                     NaN                 NaN            NaN
# 3                     NaN                 NaN            NaN
# 4                     NaN                 NaN            NaN
# ...                   ...                 ...            ...
# 3435                  NaN                 NaN            NaN
# 3436                  NaN                 NaN            NaN
# 3437                  NaN                 NaN            NaN
# 3438                  NaN                 NaN            NaN
# 3439                  NaN                 NaN            NaN
#
#      clearance_left_foot clearance_other clearance_right_foot counterpress  \
# 0                    NaN             NaN                  NaN          NaN
# 1                    NaN             NaN                  NaN          NaN
# 2                    NaN             NaN                  NaN          NaN
# 3                    NaN             NaN                  NaN          NaN
# 4                    NaN             NaN                  NaN          NaN
# ...                  ...             ...                  ...          ...
# 3435                 NaN             NaN                  NaN          NaN
# 3436                 NaN             NaN                  NaN          NaN
# 3437                 NaN             NaN                  NaN          NaN
# 3438                 NaN             NaN                  NaN          NaN
# 3439                 NaN             NaN                  NaN          NaN
#
#      dribble_nutmeg dribble_outcome dribble_overrun duel_outcome duel_type  \
# 0               NaN             NaN             NaN          NaN       NaN
# 1               NaN             NaN             NaN          NaN       NaN
# 2               NaN             NaN             NaN          NaN       NaN
# 3               NaN             NaN             NaN          NaN       NaN
# 4               NaN             NaN             NaN          NaN       NaN
# ...             ...             ...             ...          ...       ...
# 3435            NaN             NaN             NaN          NaN       NaN
# 3436            NaN             NaN             NaN          NaN       NaN
# 3437            NaN             NaN             NaN          NaN       NaN
# 3438            NaN             NaN             NaN          NaN       NaN
# 3439            NaN             NaN             NaN          NaN       NaN
#
#       duration foul_committed_card foul_committed_offensive  \
# 0          0.0                 NaN                      NaN
# 1          0.0                 NaN                      NaN
# 2          0.0                 NaN                      NaN
# 3          0.0                 NaN                      NaN
# 4          0.0                 NaN                      NaN
# ...        ...                 ...                      ...
# 3435       0.0                 NaN                      NaN
# 3436       0.0                 NaN                      NaN
# 3437       0.0                 NaN                      NaN
# 3438       0.0                 NaN                      NaN
# 3439       0.0                 NaN                      NaN
#
#      foul_won_defensive goalkeeper_body_part goalkeeper_end_location  \
# 0                   NaN                  NaN                     NaN
# 1                   NaN                  NaN                     NaN
# 2                   NaN                  NaN                     NaN
# 3                   NaN                  NaN                     NaN
# 4                   NaN                  NaN                     NaN
# ...                 ...                  ...                     ...
# 3435                NaN                  NaN                     NaN
# 3436                NaN                  NaN                     NaN
# 3437                NaN                  NaN                     NaN
# 3438                NaN                  NaN                     NaN
# 3439                NaN                  NaN                     NaN
#
#      goalkeeper_outcome goalkeeper_position goalkeeper_punched_out  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3                   NaN                 NaN                    NaN
# 4                   NaN                 NaN                    NaN
# ...                 ...                 ...                    ...
# 3435                NaN                 NaN                    NaN
# 3436                NaN                 NaN                    NaN
# 3437                NaN                 NaN                    NaN
# 3438                NaN                 NaN                    NaN
# 3439                NaN                 NaN                    NaN
#
#      goalkeeper_shot_saved_off_target goalkeeper_shot_saved_to_post  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
# ...                               ...                           ...
# 3435                              NaN                           NaN
# 3436                              NaN                           NaN
# 3437                              NaN                           NaN
# 3438                              NaN                           NaN
# 3439                              NaN                           NaN
#
#      goalkeeper_technique goalkeeper_type  \
# 0                     NaN             NaN
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 3435                  NaN             NaN
# 3436                  NaN             NaN
# 3437                  NaN             NaN
# 3438                  NaN             NaN
# 3439                  NaN             NaN
#
#                                         id  index interception_outcome  \
# 0     848384ba-8ed0-48dc-8b0b-9795a5ce8ca3      1                  NaN
# 1     f2a8e7f6-21df-43da-9169-8d9fff669f63      2                  NaN
# 2     454ff50d-7737-4d6e-bd23-f986d3a723fa      3                  NaN
# 3     df99d82d-139d-4148-ab88-326e377bd4f4      4                  NaN
# 4     cc189e43-d56a-4fbe-9305-9ab53af666d6   1247                  NaN
# ...                                    ...    ...                  ...
# 3435  9c51ad37-c65d-4fdd-8e5f-3eecfb73d3ee   2909                  NaN
# 3436  4dcce2aa-bd74-4e5b-aabe-21d0f540c4cd   3198                  NaN
# 3437  9954355e-690e-42dd-884b-b6cb24f93f42   3196                  NaN
# 3438  8fbe699f-214c-4d0a-b84a-2b9eaf4778da   3197                  NaN
# 3439  c762b23a-7bb5-4be3-a51e-2f9650dda61e   3199                  NaN
#
#          location  match_id  minute off_camera  out pass_aerial_won  \
# 0             NaN   3847567       0        NaN  NaN             NaN
# 1             NaN   3847567       0        NaN  NaN             NaN
# 2             NaN   3847567       0        NaN  NaN             NaN
# 3             NaN   3847567       0        NaN  NaN             NaN
# 4             NaN   3847567      45        NaN  NaN             NaN
# ...           ...       ...     ...        ...  ...             ...
# 3435          NaN   3835319      76        NaN  NaN             NaN
# 3436          NaN   3835319      86        NaN  NaN             NaN
# 3437          NaN   3835319      85        NaN  NaN             NaN
# 3438          NaN   3835319      85        NaN  NaN             NaN
# 3439  [5.4, 32.0]   3835319      86       True  NaN             NaN
#
#       pass_angle pass_assisted_shot_id pass_body_part pass_cross  \
# 0            NaN                   NaN            NaN        NaN
# 1            NaN                   NaN            NaN        NaN
# 2            NaN                   NaN            NaN        NaN
# 3            NaN                   NaN            NaN        NaN
# 4            NaN                   NaN            NaN        NaN
# ...          ...                   ...            ...        ...
# 3435         NaN                   NaN            NaN        NaN
# 3436         NaN                   NaN            NaN        NaN
# 3437         NaN                   NaN            NaN        NaN
# 3438         NaN                   NaN            NaN        NaN
# 3439         NaN                   NaN            NaN        NaN
#
#      pass_cut_back pass_deflected pass_end_location pass_goal_assist  \
# 0              NaN            NaN               NaN              NaN
# 1              NaN            NaN               NaN              NaN
# 2              NaN            NaN               NaN              NaN
# 3              NaN            NaN               NaN              NaN
# 4              NaN            NaN               NaN              NaN
# ...            ...            ...               ...              ...
# 3435           NaN            NaN               NaN              NaN
# 3436           NaN            NaN               NaN              NaN
# 3437           NaN            NaN               NaN              NaN
# 3438           NaN            NaN               NaN              NaN
# 3439           NaN            NaN               NaN              NaN
#
#      pass_height pass_inswinging  pass_length pass_miscommunication  \
# 0            NaN             NaN          NaN                   NaN
# 1            NaN             NaN          NaN                   NaN
# 2            NaN             NaN          NaN                   NaN
# 3            NaN             NaN          NaN                   NaN
# 4            NaN             NaN          NaN                   NaN
# ...          ...             ...          ...                   ...
# 3435         NaN             NaN          NaN                   NaN
# 3436         NaN             NaN          NaN                   NaN
# 3437         NaN             NaN          NaN                   NaN
# 3438         NaN             NaN          NaN                   NaN
# 3439         NaN             NaN          NaN                   NaN
#
#      pass_no_touch pass_outcome pass_outswinging pass_recipient  \
# 0              NaN          NaN              NaN            NaN
# 1              NaN          NaN              NaN            NaN
# 2              NaN          NaN              NaN            NaN
# 3              NaN          NaN              NaN            NaN
# 4              NaN          NaN              NaN            NaN
# ...            ...          ...              ...            ...
# 3435           NaN          NaN              NaN            NaN
# 3436           NaN          NaN              NaN            NaN
# 3437           NaN          NaN              NaN            NaN
# 3438           NaN          NaN              NaN            NaN
# 3439           NaN          NaN              NaN            NaN
#
#      pass_shot_assist pass_straight pass_switch pass_technique  \
# 0                 NaN           NaN         NaN            NaN
# 1                 NaN           NaN         NaN            NaN
# 2                 NaN           NaN         NaN            NaN
# 3                 NaN           NaN         NaN            NaN
# 4                 NaN           NaN         NaN            NaN
# ...               ...           ...         ...            ...
# 3435              NaN           NaN         NaN            NaN
# 3436              NaN           NaN         NaN            NaN
# 3437              NaN           NaN         NaN            NaN
# 3438              NaN           NaN         NaN            NaN
# 3439              NaN           NaN         NaN            NaN
#
#      pass_through_ball pass_type  period   play_pattern  \
# 0                  NaN       NaN       1   Regular Play
# 1                  NaN       NaN       1   Regular Play
# 2                  NaN       NaN       1   Regular Play
# 3                  NaN       NaN       1   Regular Play
# 4                  NaN       NaN       2  From Throw In
# ...                ...       ...     ...            ...
# 3435               NaN       NaN       2   Regular Play
# 3436               NaN       NaN       2   Regular Play
# 3437               NaN       NaN       2   Regular Play
# 3438               NaN       NaN       2   Regular Play
# 3439               NaN       NaN       2          Other
#
#                      player  player_id              position  possession  \
# 0                       NaN        NaN                   NaN           1
# 1                       NaN        NaN                   NaN           1
# 2                       NaN        NaN                   NaN           1
# 3                       NaN        NaN                   NaN           1
# 4                       NaN        NaN                   NaN          91
# ...                     ...        ...                   ...         ...
# 3435  Viktoria Schnaderbeck    10235.0      Left Center Back         145
# 3436      Laura Feiersinger    10242.0  Left Center Midfield         165
# 3437      Laura Feiersinger    10242.0  Left Center Midfield         165
# 3438        Leah Williamson    18999.0      Left Center Back         165
# 3439                    NaN        NaN                   NaN         166
#
#       possession_team  possession_team_id  \
# 0     England Women's                 865
# 1     England Women's                 865
# 2     England Women's                 865
# 3     England Women's                 865
# 4     England Women's                 865
# ...               ...                 ...
# 3435  England Women's                 865
# 3436  Austria Women's                 859
# 3437  Austria Women's                 859
# 3438  Austria Women's                 859
# 3439  Austria Women's                 859
#
#                               related_events  second shot_aerial_won  \
# 0                                        NaN       0             NaN
# 1                                        NaN       0             NaN
# 2     [df99d82d-139d-4148-ab88-326e377bd4f4]       0             NaN
# 3     [454ff50d-7737-4d6e-bd23-f986d3a723fa]       0             NaN
# 4     [462105b1-2658-4c3c-8e65-e09f72eac3f4]       0             NaN
# ...                                      ...     ...             ...
# 3435                                     NaN      24             NaN
# 3436                                     NaN      18             NaN
# 3437                                     NaN      26             NaN
# 3438                                     NaN      42             NaN
# 3439                                     NaN      20             NaN
#
#      shot_body_part shot_end_location shot_first_time shot_freeze_frame  \
# 0               NaN               NaN             NaN               NaN
# 1               NaN               NaN             NaN               NaN
# 2               NaN               NaN             NaN               NaN
# 3               NaN               NaN             NaN               NaN
# 4               NaN               NaN             NaN               NaN
# ...             ...               ...             ...               ...
# 3435            NaN               NaN             NaN               NaN
# 3436            NaN               NaN             NaN               NaN
# 3437            NaN               NaN             NaN               NaN
# 3438            NaN               NaN             NaN               NaN
# 3439            NaN               NaN             NaN               NaN
#
#      shot_key_pass_id shot_one_on_one shot_outcome shot_saved_off_target  \
# 0                 NaN             NaN          NaN                   NaN
# 1                 NaN             NaN          NaN                   NaN
# 2                 NaN             NaN          NaN                   NaN
# 3                 NaN             NaN          NaN                   NaN
# 4                 NaN             NaN          NaN                   NaN
# ...               ...             ...          ...                   ...
# 3435              NaN             NaN          NaN                   NaN
# 3436              NaN             NaN          NaN                   NaN
# 3437              NaN             NaN          NaN                   NaN
# 3438              NaN             NaN          NaN                   NaN
# 3439              NaN             NaN          NaN                   NaN
#
#      shot_saved_to_post  shot_statsbomb_xg shot_technique shot_type  \
# 0                   NaN                NaN            NaN       NaN
# 1                   NaN                NaN            NaN       NaN
# 2                   NaN                NaN            NaN       NaN
# 3                   NaN                NaN            NaN       NaN
# 4                   NaN                NaN            NaN       NaN
# ...                 ...                ...            ...       ...
# 3435                NaN                NaN            NaN       NaN
# 3436                NaN                NaN            NaN       NaN
# 3437                NaN                NaN            NaN       NaN
# 3438                NaN                NaN            NaN       NaN
# 3439                NaN                NaN            NaN       NaN
#
#      substitution_outcome substitution_replacement  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
# ...                   ...                      ...
# 3435             Tactical         Marina Georgieva
# 3436               Injury   Marie Therese Höbinger
# 3437                  NaN                      NaN
# 3438                  NaN                      NaN
# 3439                  NaN                      NaN
#
#                                                 tactics             team  \
# 0     {'formation': 4231, 'lineup': [{'player': {'id...  England Women's
# 1     {'formation': 433, 'lineup': [{'player': {'id'...  Germany Women's
# 2                                                   NaN  Germany Women's
# 3                                                   NaN  England Women's
# 4                                                   NaN  England Women's
# ...                                                 ...              ...
# 3435                                                NaN  Austria Women's
# 3436                                                NaN  Austria Women's
# 3437                                                NaN  Austria Women's
# 3438                                                NaN  England Women's
# 3439                                                NaN  Austria Women's
#
#          timestamp               type under_pressure block_offensive  \
# 0     00:00:00.000        Starting XI            NaN             NaN
# 1     00:00:00.000        Starting XI            NaN             NaN
# 2     00:00:00.000         Half Start            NaN             NaN
# 3     00:00:00.000         Half Start            NaN             NaN
# 4     00:00:00.000         Half Start            NaN             NaN
# ...            ...                ...            ...             ...
# 3435  00:31:24.189       Substitution            NaN             NaN
# 3436  00:41:18.770       Substitution            NaN             NaN
# 3437  00:40:26.784    Injury Stoppage            NaN             NaN
# 3438  00:40:42.898    Injury Stoppage            NaN             NaN
# 3439  00:41:20.929  Referee Ball-Drop            NaN             NaN
#
#      dribble_no_touch foul_committed_advantage foul_won_advantage  \
# 0                 NaN                      NaN                NaN
# 1                 NaN                      NaN                NaN
# 2                 NaN                      NaN                NaN
# 3                 NaN                      NaN                NaN
# 4                 NaN                      NaN                NaN
# ...               ...                      ...                ...
# 3435              NaN                      NaN                NaN
# 3436              NaN                      NaN                NaN
# 3437              NaN                      NaN                NaN
# 3438              NaN                      NaN                NaN
# 3439              NaN                      NaN                NaN
#
#      miscontrol_aerial_won shot_open_goal block_save_block  \
# 0                      NaN            NaN              NaN
# 1                      NaN            NaN              NaN
# 2                      NaN            NaN              NaN
# 3                      NaN            NaN              NaN
# 4                      NaN            NaN              NaN
# ...                    ...            ...              ...
# 3435                   NaN            NaN              NaN
# 3436                   NaN            NaN              NaN
# 3437                   NaN            NaN              NaN
# 3438                   NaN            NaN              NaN
# 3439                   NaN            NaN              NaN
#
#      foul_committed_type shot_deflected injury_stoppage_in_chain  \
# 0                    NaN            NaN                      NaN
# 1                    NaN            NaN                      NaN
# 2                    NaN            NaN                      NaN
# 3                    NaN            NaN                      NaN
# 4                    NaN            NaN                      NaN
# ...                  ...            ...                      ...
# 3435                 NaN            NaN                      NaN
# 3436                 NaN            NaN                      NaN
# 3437                 NaN            NaN                     True
# 3438                 NaN            NaN                      NaN
# 3439                 NaN            NaN                      NaN
#
#      foul_committed_penalty foul_won_penalty goalkeeper_success_in_play  \
# 0                       NaN              NaN                        NaN
# 1                       NaN              NaN                        NaN
# 2                       NaN              NaN                        NaN
# 3                       NaN              NaN                        NaN
# 4                       NaN              NaN                        NaN
# ...                     ...              ...                        ...
# 3435                    NaN              NaN                        NaN
# 3436                    NaN              NaN                        NaN
# 3437                    NaN              NaN                        NaN
# 3438                    NaN              NaN                        NaN
# 3439                    NaN              NaN                        NaN
#
#      half_start_late_video_start
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3435                         NaN
# 3436                         NaN
# 3437                         NaN
# 3438                         NaN
# 3439                         NaN
#
# [104988 rows x 107 columns]

# %%
all_events.reset_index()
# Out:
#         level_0 50_50 bad_behaviour_card ball_receipt_outcome  \
# 0             0   NaN                NaN                  NaN
# 1             1   NaN                NaN                  NaN
# 2             2   NaN                NaN                  NaN
# 3             3   NaN                NaN                  NaN
# 4             4   NaN                NaN                  NaN
# ...         ...   ...                ...                  ...
# 104983     3435   NaN                NaN                  NaN
# 104984     3436   NaN                NaN                  NaN
# 104985     3437   NaN                NaN                  NaN
# 104986     3438   NaN                NaN                  NaN
# 104987     3439   NaN                NaN                  NaN
#
#        ball_recovery_offensive ball_recovery_recovery_failure  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ...                        ...                            ...
# 104983                     NaN                            NaN
# 104984                     NaN                            NaN
# 104985                     NaN                            NaN
# 104986                     NaN                            NaN
# 104987                     NaN                            NaN
#
#        block_deflection carry_end_location clearance_aerial_won  \
# 0                   NaN                NaN                  NaN
# 1                   NaN                NaN                  NaN
# 2                   NaN                NaN                  NaN
# 3                   NaN                NaN                  NaN
# 4                   NaN                NaN                  NaN
# ...                 ...                ...                  ...
# 104983              NaN                NaN                  NaN
# 104984              NaN                NaN                  NaN
# 104985              NaN                NaN                  NaN
# 104986              NaN                NaN                  NaN
# 104987              NaN                NaN                  NaN
#
#        clearance_body_part clearance_head clearance_left_foot clearance_other  \
# 0                      NaN            NaN                 NaN             NaN
# 1                      NaN            NaN                 NaN             NaN
# 2                      NaN            NaN                 NaN             NaN
# 3                      NaN            NaN                 NaN             NaN
# 4                      NaN            NaN                 NaN             NaN
# ...                    ...            ...                 ...             ...
# 104983                 NaN            NaN                 NaN             NaN
# 104984                 NaN            NaN                 NaN             NaN
# 104985                 NaN            NaN                 NaN             NaN
# 104986                 NaN            NaN                 NaN             NaN
# 104987                 NaN            NaN                 NaN             NaN
#
#        clearance_right_foot counterpress dribble_nutmeg dribble_outcome  \
# 0                       NaN          NaN            NaN             NaN
# 1                       NaN          NaN            NaN             NaN
# 2                       NaN          NaN            NaN             NaN
# 3                       NaN          NaN            NaN             NaN
# 4                       NaN          NaN            NaN             NaN
# ...                     ...          ...            ...             ...
# 104983                  NaN          NaN            NaN             NaN
# 104984                  NaN          NaN            NaN             NaN
# 104985                  NaN          NaN            NaN             NaN
# 104986                  NaN          NaN            NaN             NaN
# 104987                  NaN          NaN            NaN             NaN
#
#        dribble_overrun duel_outcome duel_type  duration foul_committed_card  \
# 0                  NaN          NaN       NaN       0.0                 NaN
# 1                  NaN          NaN       NaN       0.0                 NaN
# 2                  NaN          NaN       NaN       0.0                 NaN
# 3                  NaN          NaN       NaN       0.0                 NaN
# 4                  NaN          NaN       NaN       0.0                 NaN
# ...                ...          ...       ...       ...                 ...
# 104983             NaN          NaN       NaN       0.0                 NaN
# 104984             NaN          NaN       NaN       0.0                 NaN
# 104985             NaN          NaN       NaN       0.0                 NaN
# 104986             NaN          NaN       NaN       0.0                 NaN
# 104987             NaN          NaN       NaN       0.0                 NaN
#
#        foul_committed_offensive foul_won_defensive goalkeeper_body_part  \
# 0                           NaN                NaN                  NaN
# 1                           NaN                NaN                  NaN
# 2                           NaN                NaN                  NaN
# 3                           NaN                NaN                  NaN
# 4                           NaN                NaN                  NaN
# ...                         ...                ...                  ...
# 104983                      NaN                NaN                  NaN
# 104984                      NaN                NaN                  NaN
# 104985                      NaN                NaN                  NaN
# 104986                      NaN                NaN                  NaN
# 104987                      NaN                NaN                  NaN
#
#        goalkeeper_end_location goalkeeper_outcome goalkeeper_position  \
# 0                          NaN                NaN                 NaN
# 1                          NaN                NaN                 NaN
# 2                          NaN                NaN                 NaN
# 3                          NaN                NaN                 NaN
# 4                          NaN                NaN                 NaN
# ...                        ...                ...                 ...
# 104983                     NaN                NaN                 NaN
# 104984                     NaN                NaN                 NaN
# 104985                     NaN                NaN                 NaN
# 104986                     NaN                NaN                 NaN
# 104987                     NaN                NaN                 NaN
#
#        goalkeeper_punched_out goalkeeper_shot_saved_off_target  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
# 3                         NaN                              NaN
# 4                         NaN                              NaN
# ...                       ...                              ...
# 104983                    NaN                              NaN
# 104984                    NaN                              NaN
# 104985                    NaN                              NaN
# 104986                    NaN                              NaN
# 104987                    NaN                              NaN
#
#        goalkeeper_shot_saved_to_post goalkeeper_technique goalkeeper_type  \
# 0                                NaN                  NaN             NaN
# 1                                NaN                  NaN             NaN
# 2                                NaN                  NaN             NaN
# 3                                NaN                  NaN             NaN
# 4                                NaN                  NaN             NaN
# ...                              ...                  ...             ...
# 104983                           NaN                  NaN             NaN
# 104984                           NaN                  NaN             NaN
# 104985                           NaN                  NaN             NaN
# 104986                           NaN                  NaN             NaN
# 104987                           NaN                  NaN             NaN
#
#                                           id  index interception_outcome  \
# 0       848384ba-8ed0-48dc-8b0b-9795a5ce8ca3      1                  NaN
# 1       f2a8e7f6-21df-43da-9169-8d9fff669f63      2                  NaN
# 2       454ff50d-7737-4d6e-bd23-f986d3a723fa      3                  NaN
# 3       df99d82d-139d-4148-ab88-326e377bd4f4      4                  NaN
# 4       cc189e43-d56a-4fbe-9305-9ab53af666d6   1247                  NaN
# ...                                      ...    ...                  ...
# 104983  9c51ad37-c65d-4fdd-8e5f-3eecfb73d3ee   2909                  NaN
# 104984  4dcce2aa-bd74-4e5b-aabe-21d0f540c4cd   3198                  NaN
# 104985  9954355e-690e-42dd-884b-b6cb24f93f42   3196                  NaN
# 104986  8fbe699f-214c-4d0a-b84a-2b9eaf4778da   3197                  NaN
# 104987  c762b23a-7bb5-4be3-a51e-2f9650dda61e   3199                  NaN
#
#            location  match_id  minute off_camera  out pass_aerial_won  \
# 0               NaN   3847567       0        NaN  NaN             NaN
# 1               NaN   3847567       0        NaN  NaN             NaN
# 2               NaN   3847567       0        NaN  NaN             NaN
# 3               NaN   3847567       0        NaN  NaN             NaN
# 4               NaN   3847567      45        NaN  NaN             NaN
# ...             ...       ...     ...        ...  ...             ...
# 104983          NaN   3835319      76        NaN  NaN             NaN
# 104984          NaN   3835319      86        NaN  NaN             NaN
# 104985          NaN   3835319      85        NaN  NaN             NaN
# 104986          NaN   3835319      85        NaN  NaN             NaN
# 104987  [5.4, 32.0]   3835319      86       True  NaN             NaN
#
#         pass_angle pass_assisted_shot_id pass_body_part pass_cross  \
# 0              NaN                   NaN            NaN        NaN
# 1              NaN                   NaN            NaN        NaN
# 2              NaN                   NaN            NaN        NaN
# 3              NaN                   NaN            NaN        NaN
# 4              NaN                   NaN            NaN        NaN
# ...            ...                   ...            ...        ...
# 104983         NaN                   NaN            NaN        NaN
# 104984         NaN                   NaN            NaN        NaN
# 104985         NaN                   NaN            NaN        NaN
# 104986         NaN                   NaN            NaN        NaN
# 104987         NaN                   NaN            NaN        NaN
#
#        pass_cut_back pass_deflected pass_end_location pass_goal_assist  \
# 0                NaN            NaN               NaN              NaN
# 1                NaN            NaN               NaN              NaN
# 2                NaN            NaN               NaN              NaN
# 3                NaN            NaN               NaN              NaN
# 4                NaN            NaN               NaN              NaN
# ...              ...            ...               ...              ...
# 104983           NaN            NaN               NaN              NaN
# 104984           NaN            NaN               NaN              NaN
# 104985           NaN            NaN               NaN              NaN
# 104986           NaN            NaN               NaN              NaN
# 104987           NaN            NaN               NaN              NaN
#
#        pass_height pass_inswinging  pass_length pass_miscommunication  \
# 0              NaN             NaN          NaN                   NaN
# 1              NaN             NaN          NaN                   NaN
# 2              NaN             NaN          NaN                   NaN
# 3              NaN             NaN          NaN                   NaN
# 4              NaN             NaN          NaN                   NaN
# ...            ...             ...          ...                   ...
# 104983         NaN             NaN          NaN                   NaN
# 104984         NaN             NaN          NaN                   NaN
# 104985         NaN             NaN          NaN                   NaN
# 104986         NaN             NaN          NaN                   NaN
# 104987         NaN             NaN          NaN                   NaN
#
#        pass_no_touch pass_outcome pass_outswinging pass_recipient  \
# 0                NaN          NaN              NaN            NaN
# 1                NaN          NaN              NaN            NaN
# 2                NaN          NaN              NaN            NaN
# 3                NaN          NaN              NaN            NaN
# 4                NaN          NaN              NaN            NaN
# ...              ...          ...              ...            ...
# 104983           NaN          NaN              NaN            NaN
# 104984           NaN          NaN              NaN            NaN
# 104985           NaN          NaN              NaN            NaN
# 104986           NaN          NaN              NaN            NaN
# 104987           NaN          NaN              NaN            NaN
#
#        pass_shot_assist pass_straight pass_switch pass_technique  \
# 0                   NaN           NaN         NaN            NaN
# 1                   NaN           NaN         NaN            NaN
# 2                   NaN           NaN         NaN            NaN
# 3                   NaN           NaN         NaN            NaN
# 4                   NaN           NaN         NaN            NaN
# ...                 ...           ...         ...            ...
# 104983              NaN           NaN         NaN            NaN
# 104984              NaN           NaN         NaN            NaN
# 104985              NaN           NaN         NaN            NaN
# 104986              NaN           NaN         NaN            NaN
# 104987              NaN           NaN         NaN            NaN
#
#        pass_through_ball pass_type  period   play_pattern  \
# 0                    NaN       NaN       1   Regular Play
# 1                    NaN       NaN       1   Regular Play
# 2                    NaN       NaN       1   Regular Play
# 3                    NaN       NaN       1   Regular Play
# 4                    NaN       NaN       2  From Throw In
# ...                  ...       ...     ...            ...
# 104983               NaN       NaN       2   Regular Play
# 104984               NaN       NaN       2   Regular Play
# 104985               NaN       NaN       2   Regular Play
# 104986               NaN       NaN       2   Regular Play
# 104987               NaN       NaN       2          Other
#
#                        player  player_id              position  possession  \
# 0                         NaN        NaN                   NaN           1
# 1                         NaN        NaN                   NaN           1
# 2                         NaN        NaN                   NaN           1
# 3                         NaN        NaN                   NaN           1
# 4                         NaN        NaN                   NaN          91
# ...                       ...        ...                   ...         ...
# 104983  Viktoria Schnaderbeck    10235.0      Left Center Back         145
# 104984      Laura Feiersinger    10242.0  Left Center Midfield         165
# 104985      Laura Feiersinger    10242.0  Left Center Midfield         165
# 104986        Leah Williamson    18999.0      Left Center Back         165
# 104987                    NaN        NaN                   NaN         166
#
#         possession_team  possession_team_id  \
# 0       England Women's                 865
# 1       England Women's                 865
# 2       England Women's                 865
# 3       England Women's                 865
# 4       England Women's                 865
# ...                 ...                 ...
# 104983  England Women's                 865
# 104984  Austria Women's                 859
# 104985  Austria Women's                 859
# 104986  Austria Women's                 859
# 104987  Austria Women's                 859
#
#                                 related_events  second shot_aerial_won  \
# 0                                          NaN       0             NaN
# 1                                          NaN       0             NaN
# 2       [df99d82d-139d-4148-ab88-326e377bd4f4]       0             NaN
# 3       [454ff50d-7737-4d6e-bd23-f986d3a723fa]       0             NaN
# 4       [462105b1-2658-4c3c-8e65-e09f72eac3f4]       0             NaN
# ...                                        ...     ...             ...
# 104983                                     NaN      24             NaN
# 104984                                     NaN      18             NaN
# 104985                                     NaN      26             NaN
# 104986                                     NaN      42             NaN
# 104987                                     NaN      20             NaN
#
#        shot_body_part shot_end_location shot_first_time shot_freeze_frame  \
# 0                 NaN               NaN             NaN               NaN
# 1                 NaN               NaN             NaN               NaN
# 2                 NaN               NaN             NaN               NaN
# 3                 NaN               NaN             NaN               NaN
# 4                 NaN               NaN             NaN               NaN
# ...               ...               ...             ...               ...
# 104983            NaN               NaN             NaN               NaN
# 104984            NaN               NaN             NaN               NaN
# 104985            NaN               NaN             NaN               NaN
# 104986            NaN               NaN             NaN               NaN
# 104987            NaN               NaN             NaN               NaN
#
#        shot_key_pass_id shot_one_on_one shot_outcome shot_saved_off_target  \
# 0                   NaN             NaN          NaN                   NaN
# 1                   NaN             NaN          NaN                   NaN
# 2                   NaN             NaN          NaN                   NaN
# 3                   NaN             NaN          NaN                   NaN
# 4                   NaN             NaN          NaN                   NaN
# ...                 ...             ...          ...                   ...
# 104983              NaN             NaN          NaN                   NaN
# 104984              NaN             NaN          NaN                   NaN
# 104985              NaN             NaN          NaN                   NaN
# 104986              NaN             NaN          NaN                   NaN
# 104987              NaN             NaN          NaN                   NaN
#
#        shot_saved_to_post  shot_statsbomb_xg shot_technique shot_type  \
# 0                     NaN                NaN            NaN       NaN
# 1                     NaN                NaN            NaN       NaN
# 2                     NaN                NaN            NaN       NaN
# 3                     NaN                NaN            NaN       NaN
# 4                     NaN                NaN            NaN       NaN
# ...                   ...                ...            ...       ...
# 104983                NaN                NaN            NaN       NaN
# 104984                NaN                NaN            NaN       NaN
# 104985                NaN                NaN            NaN       NaN
# 104986                NaN                NaN            NaN       NaN
# 104987                NaN                NaN            NaN       NaN
#
#        substitution_outcome substitution_replacement  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# ...                     ...                      ...
# 104983             Tactical         Marina Georgieva
# 104984               Injury   Marie Therese Höbinger
# 104985                  NaN                      NaN
# 104986                  NaN                      NaN
# 104987                  NaN                      NaN
#
#                                                   tactics             team  \
# 0       {'formation': 4231, 'lineup': [{'player': {'id...  England Women's
# 1       {'formation': 433, 'lineup': [{'player': {'id'...  Germany Women's
# 2                                                     NaN  Germany Women's
# 3                                                     NaN  England Women's
# 4                                                     NaN  England Women's
# ...                                                   ...              ...
# 104983                                                NaN  Austria Women's
# 104984                                                NaN  Austria Women's
# 104985                                                NaN  Austria Women's
# 104986                                                NaN  England Women's
# 104987                                                NaN  Austria Women's
#
#            timestamp               type under_pressure block_offensive  \
# 0       00:00:00.000        Starting XI            NaN             NaN
# 1       00:00:00.000        Starting XI            NaN             NaN
# 2       00:00:00.000         Half Start            NaN             NaN
# 3       00:00:00.000         Half Start            NaN             NaN
# 4       00:00:00.000         Half Start            NaN             NaN
# ...              ...                ...            ...             ...
# 104983  00:31:24.189       Substitution            NaN             NaN
# 104984  00:41:18.770       Substitution            NaN             NaN
# 104985  00:40:26.784    Injury Stoppage            NaN             NaN
# 104986  00:40:42.898    Injury Stoppage            NaN             NaN
# 104987  00:41:20.929  Referee Ball-Drop            NaN             NaN
#
#        dribble_no_touch foul_committed_advantage foul_won_advantage  \
# 0                   NaN                      NaN                NaN
# 1                   NaN                      NaN                NaN
# 2                   NaN                      NaN                NaN
# 3                   NaN                      NaN                NaN
# 4                   NaN                      NaN                NaN
# ...                 ...                      ...                ...
# 104983              NaN                      NaN                NaN
# 104984              NaN                      NaN                NaN
# 104985              NaN                      NaN                NaN
# 104986              NaN                      NaN                NaN
# 104987              NaN                      NaN                NaN
#
#        miscontrol_aerial_won shot_open_goal block_save_block  \
# 0                        NaN            NaN              NaN
# 1                        NaN            NaN              NaN
# 2                        NaN            NaN              NaN
# 3                        NaN            NaN              NaN
# 4                        NaN            NaN              NaN
# ...                      ...            ...              ...
# 104983                   NaN            NaN              NaN
# 104984                   NaN            NaN              NaN
# 104985                   NaN            NaN              NaN
# 104986                   NaN            NaN              NaN
# 104987                   NaN            NaN              NaN
#
#        foul_committed_type shot_deflected injury_stoppage_in_chain  \
# 0                      NaN            NaN                      NaN
# 1                      NaN            NaN                      NaN
# 2                      NaN            NaN                      NaN
# 3                      NaN            NaN                      NaN
# 4                      NaN            NaN                      NaN
# ...                    ...            ...                      ...
# 104983                 NaN            NaN                      NaN
# 104984                 NaN            NaN                      NaN
# 104985                 NaN            NaN                     True
# 104986                 NaN            NaN                      NaN
# 104987                 NaN            NaN                      NaN
#
#        foul_committed_penalty foul_won_penalty goalkeeper_success_in_play  \
# 0                         NaN              NaN                        NaN
# 1                         NaN              NaN                        NaN
# 2                         NaN              NaN                        NaN
# 3                         NaN              NaN                        NaN
# 4                         NaN              NaN                        NaN
# ...                       ...              ...                        ...
# 104983                    NaN              NaN                        NaN
# 104984                    NaN              NaN                        NaN
# 104985                    NaN              NaN                        NaN
# 104986                    NaN              NaN                        NaN
# 104987                    NaN              NaN                        NaN
#
#        half_start_late_video_start
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 104983                         NaN
# 104984                         NaN
# 104985                         NaN
# 104986                         NaN
# 104987                         NaN
#
# [104988 rows x 108 columns]

# %%
all_events.to_csv('events_test_3.csv')

# %%
'location'
'pass_end_location'

all_events['location_x'] = 

for i in all_events['location']:
    all_events['location'].strip([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-776e1ff7c3bc> in <module>
#       1 for i in all_events['location']:
# ----> 2     all_events['location'].strip([])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
id_team_1 = 771 
id_team_2 = 782
start_location_x_team_1 = []
end_location_x_team_1 = []
start_location_y_team_1 = []
end_location_y_team_1 = []
start_location_x_team_2 = []
end_location_x_team_2 = []
start_location_y_team_2 = []
end_location_y_team_2 = []
player_team_1 = []
player_team_2 = []
recipient_team_1 = []
recipient_team_2 = []
for event in data_events :
    if event['type']['name'] == 'Pass' and event['team']['id'] ==    id_team_1 :
        start_location_x_team_1.append(event['location'][0])
        start_location_y_team_1.append(event['location'][1])
        end_location_x_team_1.append(event['pass']['end_location'][0])
        end_location_y_team_1.append(event['pass']['end_location'][1])
        player_team_1.append(event['player']['name'])
        
        try :
            recipient_team_1.append(event['pass']['recipient']['name'])
        except :
            recipient_team_1.append('no recipient')
        
    if event['type']['name'] == 'Pass' and event['team']['id'] == id_team_2 :
        start_location_x_team_2.append(event['location'][0])
        start_location_y_team_2.append(event['location'][1])
        end_location_x_team_2.append(event['pass']['end_location'][0])
        end_location_y_team_2.append(event['pass']['end_location'][1])
        player_team_2.append(event['player']['name'])
        
        try :
            recipient_team_2.append(event['pass']['recipient']['name'])
        except :
            recipient_team_2.append('no recipient')
pass_team_1 = pd.DataFrame()
pass_team_1['start_x'] = start_location_x_team_1
pass_team_1['start_y'] = start_location_y_team_1
pass_team_1['end_x'] = end_location_x_team_1
pass_team_1['end_y'] = end_location_y_team_1
pass_team_1['player'] = player_team_1
pass_team_1['recipient'] = recipient_team_1
pass_team_2 = pd.DataFrame()
pass_team_2['start_x'] = start_location_x_team_2
pass_team_2['start_y'] = start_location_y_team_2
pass_team_2['end_x'] = end_location_x_team_2
pass_team_2['end_y'] = end_location_y_team_2
pass_team_2['player'] = player_team_2
pass_team_2['recipient'] = recipient_team_2

# %% [markdown]
# ### Glossary

# %%
with open('Statsbomb/open-data-master/open-data-master/data/matches/43/3.json') as f:
    data = json.load(f)
with open('Statsbomb/open-data-master/open-data-master/data/events/8655.json') as f:
    data_events = json.load(f)

# %%
data_df = json_normalize(data)
data_df

# %%
data_events_df = json_normalize(data_events)
data_events_df.columns

# %% [markdown]
# ### K Means Clustering

# %%
# We want to normalize the data as variables are measured on different scales.

from sklearn import preprocessing
x = df.values # numpy array
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
#Use PCA to reduce 60 dimensions into 2 for the plot.
from sklearn.decomposition import PCA
pca = PCA(n_components = 2) # 2D PCA for the plot
reduced = pd.DataFrame(pca.fit_transform(X_norm))

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# modelling
from sklearn.cluster import KMeans
# specify the number of clusters
kmeans = KMeans(n_clusters=5)
# fit the input data
kmeans = kmeans.fit(reduced)
# get the cluster labels
labels = kmeans.predict(reduced)
# centroid values
centroid = kmeans.cluster_centers_
# cluster values
clusters = kmeans.labels_.tolist()

# %%
# Make a new data frame by adding players’ names and their clusters.
reduced['cluster'] = clusters
reduced['name'] = names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()

# %%
# visualise clustering plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="white")
ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced, legend=False,
fit_reg=False, size = 15, scatter_kws={"s": 250})
texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
texts.append(plt.text(x, y, s))
ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("PC 1", fontsize = 20)
plt.ylabel("PC 2", fontsize = 20)
plt.show()

# %%
N_clusters = 20
X_1 = np.array(pass_team_1[['start_x', 'start_y', 'end_x', 'end_y']])
X_2 = np.array(pass_team_2[['start_x', 'start_y', 'end_x', 'end_y']])
kmeans = KMeans(n_clusters = N_clusters, random_state = 0).fit(X_1)
cluster_labels = kmeans.predict(X_1)
pass_team_1['n_cluster'] = cluster_labels
centroids_1 = pd.DataFrame(data = kmeans.cluster_centers_, columns = ['start_x', 'start_y', 'end_x', 'end_y'])
kmeans = KMeans(n_clusters = N_clusters, random_state = 0).fit(X_2)
cluster_labels = kmeans.predict(X_2)
pass_team_2['n_cluster'] = cluster_labels
centroids_2 = pd.DataFrame(data = kmeans.cluster_centers_, columns = ['start_x', 'start_y', 'end_x', 'end_y'])

# %%
from mplsoccer.pitch import Pitch
from mplsoccer import Pitch, Sbopen
# from mplsoccer.statsbomb import read_event, EVENT_SLUG
from matplotlib import rcParams

# %%
pitch = Pitch(pitch_color = 'grass', line_color = 'white', stripe = True)
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_color = 'grass', line_color = 'white', stripe = True)
fig, ax = pitch.draw()
lc1 = pitch.lines(centroids_1['start_x'], centroids_1['start_y'],
                  centroids_1['end_x'], centroids_1['end_y'],
                  lw=5, transparent=True, comet=True, label='France passes',
                  color='#ad993c', ax=ax)
lc2 = pitch.lines(centroids_2['start_x'], centroids_2['start_y'],
                  centroids_2['end_x'], centroids_2['end_y'],
                  lw=5, transparent=True, comet=True, label='Belgium passes',
                  color='#ba4f45', ax=ax)
# Plot the legend
ax.legend(facecolor='#22312b', edgecolor='None', fontsize=20, loc='upper left', handlelength=4)
# Set the title
ax.set_title(f'20 Main passes France vs Belgium, World Cup 2018 Semifinal ', fontsize=30)
# Set the figure facecolor
fig.set_facecolor('#22312b')

# %%
for c in sorted(pass_team_1['n_cluster'].unique()) :
    
    pitch = Pitch(pitch_color = 'grass', line_color = 'white', stripe = True)
    fig, ax = pitch.draw()

    lc1 = pitch.lines(pass_team_1[pass_team_1['n_cluster'] == c]['start_x'], 
                      pass_team_1[pass_team_1['n_cluster'] == c]['start_y'],
                      pass_team_1[pass_team_1['n_cluster'] == c]['end_x'],
                      pass_team_1[pass_team_1['n_cluster'] == c]['end_y'],
                      lw=5, transparent=True, comet=True, label='France passes',
                      color='#ad993c', ax=ax)
# Plot the legend
    ax.legend(facecolor='#22312b', edgecolor='None', fontsize=15, loc='upper left', handlelength=3)
# Set the title
    ax.set_title(f'Cluster passes France vs Belgium, World Cup 2018 Semifinal ', fontsize=10)
# Set the figure facecolor
    fig.set_facecolor('#22312b')
    
    dic_pass_players = {}
    for player in pass_team_1[pass_team_1['n_cluster'] == c]['player'].unique() :
        dic_pass_players[player] = sum(pass_team_1[pass_team_1['n_cluster'] == c]['player'] == player)
    
    sort_pass_players = sorted(dic_pass_players.items(), key=lambda x: x[1], reverse=True)
    sort_dic_pass_players = {}
    for i in range(len(sort_pass_players)) :
        sort_dic_pass_players[sort_pass_players[i][0]] = sort_pass_players[i][1]
    i=0
    for p in list(sort_dic_pass_players.keys()) :
        plt.text(52, 117-i, p + ' ' + str(sort_dic_pass_players[p]), bbox=dict(facecolor='#22312b', edgecolor='None', alpha=0.5))
        i+=3
